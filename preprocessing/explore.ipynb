# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
orig_data = pd.read_csv("../data/full_discretised_input_data.csv")
orig_data.head()
# Out:
#    bloc  icustayid   charttime  gender           age  elixhauser  \
# 0     1          3  7245052800       0  17639.826435         0.0
# 1     2          3  7245067200       0  17639.826435         0.0
# 2     3          3  7245081600       0  17639.826435         0.0
# 3     4          3  7245096000       0  17639.826435         0.0
# 4     5          3  7245110400       0  17639.826435         0.0
#
#    re_admission  died_in_hosp  mortality_90d  Weight_kg  ...  SIRS  \
# 0             0             0              1       77.5  ...     4
# 1             0             0              1       77.5  ...     3
# 2             0             0              1       77.5  ...     3
# 3             0             0              1       77.5  ...     3
# 4             0             0              1       77.5  ...     3
#
#    median_dose_vaso  max_dose_vaso  input_total_tev  input_4hourly_tev  \
# 0               0.0            0.0           3500.0             2100.0
# ...

# %%
orig_data.groupby(['icustayid']).agg({'bloc':'max'})['bloc'].value_counts()
# Out:
# 14    3047
# 20    3008
# 15    2085
# 12    1496
# 13    1373
# 16    1244
# 11    1167
# 10     815
# 17     793
# 9      784
# 18     651
# 19     492
# 8      315
# 7      213
# 6      148
# 5       98
# 3       70
# 4       62
# 2       29
# 1        8
# Name: bloc, dtype: int64
